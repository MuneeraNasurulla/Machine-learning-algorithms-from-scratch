# %% [markdown]
# <a href="https://colab.research.google.com/github/MuneeraNasurulla/Machine-learning-algorithms-from-scratch/blob/main/day_6_L1%2CL2_(From_scratch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=np.array([2.1,3.8,6.5,9.2,11.3])

# %%
#after array design matrix
x_b=np.c_[np.ones((x.shape[0],1)),x]
x_b
# Out:
# array([[1., 1.],
#        [1., 2.],
#        [1., 3.],
#        [1., 4.],
#        [1., 5.]])

# %%
alpha_ridge=1.0
alpha_lasso=0.1
num_iterations=1000
learning_rate=0.01

# %%
def lasso_regression(x,y,alpha,num_iterations,learning_rate):
  m,n=x.shape
  theta = np.zeros(n)
  for _ in range(num_iterations):
    y_pred=x.dot(theta)
    gradient=(x.T.dot(y_pred-y)+alpha*np.sign(theta))/m
    theta-=learning_rate*gradient

  return theta

# %%
def ridge_regression(x,y,alpha,num_iterations,learning_rate):
  m,n=x.shape
  theta = np.zeros(n)
  for _ in range(num_iterations):
    y_pred=x.dot(theta)
    gradient=(x.T.dot(y_pred-y)+alpha*theta)/m
    theta-=learning_rate*gradient

  return theta

# %%
# ridge and lasso what is differnece
theta_ridge=ridge_regression(x_b,y,alpha_ridge,num_iterations,learning_rate)
theta_lasso=lasso_regression(x_b,y,alpha_lasso,num_iterations,learning_rate)

# %%
plt.scatter(x,y,label='Data')
plt.plot(x,x_b.dot(theta_ridge),label=f'Ridge(L2) Regression',color='r')
plt.plot(x,x_b.dot(theta_lasso),label=f'Lasso(L1) Regression',color='g')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
